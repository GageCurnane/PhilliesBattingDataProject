# %% [markdown]
# # Introduction to Phillies Batting Dataset (2015-2023)

# %% [markdown]
# ## Brief Overview of Dataset

# %% [markdown]
# This dataset covers 31 variables and 460 rows of batting data spanning from the 2015 to 2023 season. The data contains pitchers as well, since pitchers would bat up until the year 2020.

# %% [markdown]
# ## Interest

# %% [markdown]
# This specific data set was of interest to me because it has pitchers hitting data in it as well. I thought its unique and will be interesting to manipulate the data. I also play baseball and have my whole life, so I enjoy looking through baseball data.

# %% [markdown]
# ## Source

# %% [markdown]
# I found this dataset from kaggle.
#
# The link will be below:
#
# https://www.kaggle.com/datasets/mattop/philadelphia-phillies-batting-and-pitching-data
#
# Note: The original dataset had about 5000 rows of data, but I shortened it to 460 rows to make it easier to work with.

# %% [markdown]
# ## Research Questions

# %% [markdown]
# 1. How does pitchers hitting data affect the overall dataset?
#
# 2. Will there be trends in the overall stats to see what makes the team win or lose more?

# %% [markdown]
# ## Codebook

# %% [markdown]
#  Variable Name-------------------------------------------------Description--------------------------------------Data Type----------------Possible Values / Notes
#
#     Name                             Player's full name                              String              Ex: "Mike Trout"
#
#     Age                              Player's age during the season                  Integer             Ex: 27
#
#     Games                            Number of games played                          Integer             ≥ 0
#
#     Plate_Appearances                 Number of times the player came                Integer             ≥ 0
#                                      to bat (includes walks, HBP, etc.)
#
#     At_Bats                             Number of official at-bats                   Integer             ≥ 0
#                                      (excludes walks, HBP, sacrifices)
#
#     Runs                             Number of runs scored by the player             Integer             ≥ 0
#
#     Hits                                           Total hits                        Integer             ≥ 0
#                                     (singles + doubles + triples + home runs)
#
#     Doubles                          Number of hits that were doubles                Integer             ≥ 0
#
#     Triples                          Number of hits that were triples                Integer             ≥ 0
#
#     Home_Runs                        Number of home runs                             Integer             ≥ 0
#
#     Runs_Batted_In                   Total runs batted in (RBIs)                     Integer             ≥ 0
#
#     Stolen_Bases                     Number of bases stolen successfully             Integer             ≥ 0
#
#     Caught_Stealing                  Number of times caught stealing a base          Integer             ≥ 0
#
#     Base_On_Balls                    Number of walks (BB) received                   Integer             ≥ 0
#
#     Strikeouts                       Number of times the player struck out           Integer             ≥ 0
#
#     Batting_Average                  Hits divided by at-bats (AVG)                    Float              0.000 - 1.000
#
#     On_Base_Percentage               OBP: how often a player reaches base             Float              0.000 - 1.000
#
#     Slugging_Percentage              SLG: total bases per at-bat                      Float              0.000 - 4.000 (typically < 1.000)
#
#     On_Base_Plus_Slugging_           OPS = OBP + SLG                                  Float              0.000 - 5.000 (typically < 2.000)
#     Percentage
#
#     On_Base_Plus_Slugging_ OPS+:     league- and park-adjusted OPS               Integer  0 and up      (100 = average, >100 = better)
#     Percentage_Plus                    (100 = league average)
#
#     Total_Bases                      Total number of bases from hits                  Integer            ≥ 0
#                                        (1×1B + 2×2B + 3×3B + 4×HR)
#
#     Double_Plays_Grounded_Into       Number of double plays the                       Integer            ≥ 0
#                                      player grounded into (GIDP)
#
#     Times_Hit_By_Pitch               Number of times hit by a pitch (HBP)             Integer            ≥ 0
#
#     Sacrifice_Hits                   Number of successful sacrifice bunts (SH)        Integer            ≥ 0
#
#     Sacrifice_Flies                  Number of sacrifice flies (SF)                   Integer            ≥ 0
#
#     Intentional_Bases_on_Balls       Number of intentional walks                      Integer            ≥ 0
#                                           (IBB) received
#
#     Dominant_Hand                    Player's dominant throwing hand            Categorical (String)     "Right", "Left", "Ambidextrous"
#
#     Switch_Hitter                    Whether the player is a switch hitter     Boolean or Categorical    "Yes"/"No" or True/False

# %% [markdown]
# ## Reading in Data

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)

# %%
phillies_data = pd.read_csv('PhilliesBattingData2(2015-2023).csv')

# %% [markdown]
# ## Exploration

# %%
phillies_data.head()
# Out:
#    Rank  Year Position           Name  Age  Games  Plate_Appearances  At_Bats  \
# 0     1  2023        C  J.T. Realmuto   32    135                540      489
# 1     2  2023       1B   Kody Clemens   27     47                148      139
# 2     3  2023       2B   Bryson Stott   25    151                640      585
# 3     4  2023       SS    Trea Turner   30    155                691      639
# 4     5  2023       3B      Alec Bohm   26    145                611      558
#
#    Runs  Hits  Doubles  Triples  Home_Runs  Runs_Batted_In  Stolen_Bases  \
# 0    70   123     28.0        5         20              63          16.0
# 1    15    32      7.0        0          4              13           0.0
# 2    78   164     32.0        2         15              62          31.0
# 3   102   170     35.0        5         26              76          30.0
# 4    74   153     31.0        0         20              97           4.0
#
#    Caught_Stealing  Base_On_Balls  Strikeouts  Batting_Average  \
# 0                5             35       138.0            0.252
# 1                0              8        40.0            0.230
# 2                3             39       100.0            0.280
# 3                0             45       150.0            0.266
# 4                1             42        94.0            0.274
#
#    On_Base_Percentage  Slugging_Percentage  On_Base_Plus_Slugging_Percentage  \
# 0               0.310                0.452                             0.762
# 1               0.277                0.367                             0.644
# 2               0.329                0.419                             0.747
# 3               0.320                0.459                             0.778
# 4               0.327                0.437                             0.765
#
#    On_Base_Plus_Slugging_Percentage_Plus  Total_Bases  \
# 0                                    106          221
# 1                                     75           51
# 2                                    104          245
# 3                                    111          293
# 4                                    108          244
#
#    Double_Plays_Grounded_Into  Times_Hit_By_Pitch  Sacrifice_Hits  \
# 0                        10.0                   9               0
# 1                         1.0                   1               0
# 2                        10.0                   7               1
# 3                        12.0                   6               0
# 4                        23.0                   5               0
#
#    Sacrifice_Flies  Intentional_Bases_on_Balls Dominant_Hand Switch_Hitter
# 0                5                           3         Right            No
# 1                0                           0          Left            No
# 2                8                           1          Left            No
# 3                1                           2         Right            No
# 4                6                           1         Right            No

# %%
phillies_data.shape
# Out:
# (460, 31)

# %%
phillies_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 460 entries, 0 to 459
# Data columns (total 31 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Rank                                   460 non-null    int64
#  1   Year                                   460 non-null    int64
#  2   Position                               457 non-null    object
#  3   Name                                   460 non-null    object
#  4   Age                                    460 non-null    int64
#  5   Games                                  460 non-null    int64
#  6   Plate_Appearances                      460 non-null    int64
#  7   At_Bats                                460 non-null    int64
#  8   Runs                                   460 non-null    int64
#  9   Hits                                   460 non-null    int64
#  10  Doubles                                457 non-null    float64
#  11  Triples                                460 non-null    int64
#  12  Home_Runs                              460 non-null    int64
#  13  Runs_Batted_In                         460 non-null    int64
#  14  Stolen_Bases                           455 non-null    float64
#  15  Caught_Stealing                        460 non-null    int64
#  16  Base_On_Balls                          460 non-null    int64
#  17  Strikeouts                             457 non-null    float64
#  18  Batting_Average                        460 non-null    float64
#  19  On_Base_Percentage                     460 non-null    float64
#  20  Slugging_Percentage                    455 non-null    float64
#  21  On_Base_Plus_Slugging_Percentage       460 non-null    float64
#  22  On_Base_Plus_Slugging_Percentage_Plus  460 non-null    int64
#  23  Total_Bases                            460 non-null    int64
#  24  Double_Plays_Grounded_Into             455 non-null    float64
#  25  Times_Hit_By_Pitch                     460 non-null    int64
#  26  Sacrifice_Hits                         460 non-null    int64
#  27  Sacrifice_Flies                        460 non-null    int64
#  28  Intentional_Bases_on_Balls             460 non-null    int64
#  29  Dominant_Hand                          457 non-null    object
#  30  Switch_Hitter                          460 non-null    object
# dtypes: float64(8), int64(19), object(4)
# memory usage: 111.5+ KB

# %%
phillies_data.describe()
# Out:
#              Rank         Year         Age       Games  Plate_Appearances  \
# count  460.000000   460.000000  460.000000  460.000000         460.000000
# mean    25.806522  2019.000000   27.736957   39.771739         113.776087
# std     14.886922     2.552285    3.577700   45.457947         187.854936
# min      1.000000  2015.000000   21.000000    0.000000           0.000000
# 25%     13.000000  2017.000000   25.000000    4.000000           0.000000
# 50%     25.500000  2019.000000   27.000000   23.000000          16.000000
# 75%     38.000000  2021.000000   30.000000   57.250000         138.250000
# max     56.000000  2023.000000   39.000000  162.000000         720.000000
#
#           At_Bats        Runs        Hits     Doubles     Triples   Home_Runs  \
# count  460.000000  460.000000  460.000000  457.000000  460.000000  460.000000
# mean   101.876087   13.291304   25.106522    4.857768    0.560870    3.532609
# std    168.114534   23.712924   43.931264    8.898767    1.296296    7.326276
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%     14.000000    0.500000    1.000000    0.000000    0.000000    0.000000
# 75%    127.000000   15.000000   30.000000    6.000000    0.250000    3.000000
# max    639.000000  108.000000  171.000000   42.000000   11.000000   47.000000
#
#        Runs_Batted_In  Stolen_Bases  Caught_Stealing  Base_On_Balls  \
# count      460.000000    455.000000       460.000000     460.000000
# mean        12.739130      1.595604         0.502174       9.528261
# std         23.232401      4.206035         1.322668      18.792563
# min          0.000000      0.000000         0.000000       0.000000
# 25%          0.000000      0.000000         0.000000       0.000000
# 50%          0.000000      0.000000         0.000000       0.000000
# 75%         14.000000      1.000000         0.000000      11.000000
# max        114.000000     31.000000        13.000000     126.000000
#
#        Strikeouts  Batting_Average  On_Base_Percentage  Slugging_Percentage  \
# count  457.000000       460.000000          460.000000           455.000000
# mean    25.899344         0.118307            0.158291             0.186393
# std     41.508649         0.121277            0.164371             0.199003
# min      0.000000         0.000000            0.000000             0.000000
# 25%      0.000000         0.000000            0.000000             0.000000
# 50%      5.000000         0.091000            0.144000             0.125000
# 75%     35.000000         0.235500            0.301250             0.374500
# max    215.000000         0.500000            1.000000             0.875000
#
#        On_Base_Plus_Slugging_Percentage  \
# count                        460.000000
# mean                           0.341970
# std                            0.349152
# min                            0.000000
# 25%                            0.000000
# 50%                            0.286000
# 75%                            0.690000
# max                            1.431000
#
#        On_Base_Plus_Slugging_Percentage_Plus  Total_Bases  \
# count                             460.000000   460.000000
# mean                               26.471739    41.810870
# std                                68.696494    74.103128
# min                              -100.000000     0.000000
# 25%                                 0.000000     0.000000
# 50%                                 0.000000     2.000000
# 75%                                85.000000    46.000000
# max                               279.000000   300.000000
#
#        Double_Plays_Grounded_Into  Times_Hit_By_Pitch  Sacrifice_Hits  \
# count                  455.000000          460.000000      460.000000
# mean                     2.032967            1.095652        0.571739
# std                      4.029764            2.204072        1.397658
# min                      0.000000            0.000000        0.000000
# 25%                      0.000000            0.000000        0.000000
# 50%                      0.000000            0.000000        0.000000
# 75%                      2.000000            1.000000        0.000000
# max                     23.000000           14.000000        9.000000
#
#        Sacrifice_Flies  Intentional_Bases_on_Balls
# count       460.000000                  460.000000
# mean          0.678261                    0.602174
# std           1.562345                    1.991375
# min           0.000000                    0.000000
# 25%           0.000000                    0.000000
# 50%           0.000000                    0.000000
# 75%           0.000000                    0.000000
# max          10.000000                   19.000000

# %%
phillies_data['Age'].value_counts()
# Out:
# Age
# 26    53
# 27    52
# 24    50
# 25    47
# 30    39
# 28    38
# 29    32
# 31    31
# 23    28
# 32    25
# 22    16
# 33    16
# 34    11
# 36     8
# 35     6
# 37     5
# 21     1
# 38     1
# 39     1
# Name: count, dtype: int64

# %%
phillies_data['Position'].value_counts()
# Out:
# Position
# P     259
# UT     26
# C      25
# CF     22
# OF     21
# LF     17
# RF     16
# 1B     15
# 2B     13
# SS     13
# 3B     12
# IF     10
# DH      6
# CI      1
# MI      1
# Name: count, dtype: int64

# %% [markdown]
# ## Screening

# %%
phillies_data.isnull().sum()
# Out:
# Rank                                     0
# Year                                     0
# Position                                 3
# Name                                     0
# Age                                      0
# Games                                    0
# Plate_Appearances                        0
# At_Bats                                  0
# Runs                                     0
# Hits                                     0
# Doubles                                  3
# Triples                                  0
# Home_Runs                                0
# Runs_Batted_In                           0
# Stolen_Bases                             5
# Caught_Stealing                          0
# Base_On_Balls                            0
# Strikeouts                               3
# Batting_Average                          0
# On_Base_Percentage                       0
# Slugging_Percentage                      5
# On_Base_Plus_Slugging_Percentage         0
# On_Base_Plus_Slugging_Percentage_Plus    0
# Total_Bases                              0
# Double_Plays_Grounded_Into               5
# Times_Hit_By_Pitch                       0
# Sacrifice_Hits                           0
# Sacrifice_Flies                          0
# Intentional_Bases_on_Balls               0
# Dominant_Hand                            3
# Switch_Hitter                            0
# dtype: int64

# %% [markdown]
# Position, Doubles, Stolen_Bases, Strikeouts, Slugging_Percentage, Double_Plays_Grounded_Into, Dominant_Hand columns have missing data

# %%
phillies_data.duplicated().sum()
# Out:
# np.int64(5)

# %% [markdown]
# 5 duplicated rows

# %%
phillies_data_copy = phillies_data.copy()

# %%
phillies_data_copy = np.transpose(phillies_data_copy)

# %%
phillies_data_copy.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# No duplicate columns

# %% [markdown]
# ## Cleaning

# %%
phillies_data.shape
# Out:
# (460, 31)

# %%
phillies_data[phillies_data['Position'].isnull()]
# Out:
#      Rank  Year Position           Name  Age  Games  Plate_Appearances  \
# 225    23  2019      NaN  Mitch Walding   26      2                  2
# 226    24  2019      NaN   Dylan Cozens   25      1                  1
# 227    25  2019      NaN    Rob Brantly   29      1                  1
#
#      At_Bats  Runs  Hits  Doubles  Triples  Home_Runs  Runs_Batted_In  \
# 225        2     0     0      0.0        0          0               0
# 226        1     0     0      0.0        0          0               0
# 227        1     0     0      0.0        0          0               0
#
#      Stolen_Bases  Caught_Stealing  Base_On_Balls  Strikeouts  \
# 225           0.0                0              0         2.0
# 226           0.0                0              0         0.0
# 227           0.0                0              0         1.0
#
#      Batting_Average  On_Base_Percentage  Slugging_Percentage  \
# 225              0.0                 0.0                  0.0
# 226              0.0                 0.0                  0.0
# 227              0.0                 0.0                  0.0
#
#      On_Base_Plus_Slugging_Percentage  On_Base_Plus_Slugging_Percentage_Plus  \
# 225                               0.0                                   -100
# 226                               0.0                                   -100
# 227                               0.0                                   -100
#
#      Total_Bases  Double_Plays_Grounded_Into  Times_Hit_By_Pitch  \
# 225            0                         0.0                   0
# 226            0                         0.0                   0
# 227            0                         0.0                   0
#
#      Sacrifice_Hits  Sacrifice_Flies  Intentional_Bases_on_Balls  \
# 225               0                0                           0
# 226               0                0                           0
# 227               0                0                           0
#
#     Dominant_Hand Switch_Hitter
# 225          Left            No
# 226           NaN            No
# 227          Left            No

# %%
phillies_data = phillies_data.dropna(subset = ['Position'])
phillies_data['Position'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# NAs for Position are dropped since we have no way of filling the data because there is no record of their position.

# %%
phillies_data[phillies_data['Doubles'].isnull()]
# Out:
#      Rank  Year Position              Name  Age  Games  Plate_Appearances  \
# 106     6  2021       LF  Andrew McCutchen   34    144                574
# 209     7  2019       CF     Scott Kingery   25    126                500
# 365     6  2016       LF        Cody Asche   26     71                218
#
#      At_Bats  Runs  Hits  Doubles  Triples  Home_Runs  Runs_Batted_In  \
# 106      482    78   107      NaN        1         27              80
# 209      458    64   118      NaN        4         19              55
# 365      197    22    42      NaN        0          4              18
#
#      Stolen_Bases  Caught_Stealing  Base_On_Balls  Strikeouts  \
# 106           6.0                1             81       132.0
# 209          15.0                4             34       147.0
# 365           3.0                1             18        54.0
#
#      Batting_Average  On_Base_Percentage  Slugging_Percentage  \
# 106            0.222               0.334                0.444
# 209            0.258               0.315                0.474
# 365            0.213               0.284                0.350
#
#      On_Base_Plus_Slugging_Percentage  On_Base_Plus_Slugging_Percentage_Plus  \
# 106                             0.778                                    109
# 209                             0.788                                    101
# 365                             0.635                                     69
#
#      Total_Bases  Double_Plays_Grounded_Into  Times_Hit_By_Pitch  \
# 106          214                        10.0                   4
# 209          217                         3.0                   5
# 365           69                         1.0                   2
#
#      Sacrifice_Hits  Sacrifice_Flies  Intentional_Bases_on_Balls  \
# 106               0                7                           2
# 209               1                2                           1
# 365               0                1                           0
#
#     Dominant_Hand Switch_Hitter
# 106         Right            No
# 209         Right            No
# 365          Left            No

# %%
phillies_data = phillies_data.dropna(subset = ['Doubles'])
phillies_data['Doubles'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# NAs are removed for Doubles since we cant take the mean to fill it in because they wont be accurate because some seasons they wouldnt have been the same amount of at-bats or they could have been hurt, and many other reasons.

# %%
phillies_data[phillies_data['Stolen_Bases'].isnull()]
# Out:
#      Rank  Year Position            Name  Age  Games  Plate_Appearances  \
# 8       9  2023       DH    Bryce Harper   30    126                546
# 104     4  2021       SS  Didi Gregorius   31    103                408
# 127    27  2021        P     Kyle Gibson   33     12                 28
# 210     8  2019       RF    Bryce Harper   26    157                682
# 370    11  2016       RF   Aaron Altherr   25     57                227
#
#      At_Bats  Runs  Hits  Doubles  Triples  Home_Runs  Runs_Batted_In  \
# 8        457    84   134     29.0        1         21              72
# 104      368    35    77     16.0        2         13              54
# 127       27     3     4      0.0        0          1               2
# 210      573    98   149     36.0        1         35             114
# 370      198    23    39      6.0        0          4              22
#
#      Stolen_Bases  Caught_Stealing  Base_On_Balls  Strikeouts  \
# 8             NaN                3             80       119.0
# 104           NaN                0             25        67.0
# 127           NaN                0              0         9.0
# 210           NaN                3             99       178.0
# 370           NaN                2             23         NaN
#
#      Batting_Average  On_Base_Percentage  Slugging_Percentage  \
# 8              0.293               0.401                0.499
# 104            0.209               0.270                0.370
# 127            0.148               0.148                0.259
# 210            0.260               0.372                0.510
# 370            0.197               0.300                0.288
#
#      On_Base_Plus_Slugging_Percentage  On_Base_Plus_Slugging_Percentage_Plus  \
# 8                               0.900                                    146
# 104                             0.639                                     71
# 127                             0.407                                      8
# 210                             0.882                                    126
# 370                             0.587                                     59
#
#      Total_Bases  Double_Plays_Grounded_Into  Times_Hit_By_Pitch  \
# 8            228                         NaN                   5
# 104          136                         8.0                   8
# 127            7                         0.0                   0
# 210          292                        10.0                   6
# 370           57                         4.0                   6
#
#      Sacrifice_Hits  Sacrifice_Flies  Intentional_Bases_on_Balls  \
# 8                 0                4                           8
# 104               0                7                           1
# 127               1                0                           0
# 210               0                4                          11
# 370               0                0                           2
#
#     Dominant_Hand Switch_Hitter
# 8            Left            No
# 104          Left            No
# 127         Right            No
# 210          Left            No
# 370         Right            No

# %%
phillies_data = phillies_data.dropna(subset = ['Stolen_Bases'])
phillies_data['Stolen_Bases'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# NAs are removed for Stolen Bases for the same reason as doubles, taking the mean wouldnt be accurate as it wouldnt be consistent or have any meaning.

# %%
phillies_data[phillies_data['Strikeouts'].isnull()]
# Out:
#      Rank  Year Position             Name  Age  Games  Plate_Appearances  \
# 110    10  2021       IF  Ronald Torreyes   28    111                344
# 212    10  2019        C     Andrew Knapp   27     74                160
#
#      At_Bats  Runs  Hits  Doubles  Triples  Home_Runs  Runs_Batted_In  \
# 110      318    30    77     10.0        1          7              41
# 212      136    12    29      9.0        0          2               8
#
#      Stolen_Bases  Caught_Stealing  Base_On_Balls  Strikeouts  \
# 110           2.0                1             19         NaN
# 212           0.0                0             18         NaN
#
#      Batting_Average  On_Base_Percentage  Slugging_Percentage  \
# 110            0.242               0.286                0.346
# 212            0.213               0.318                0.324
#
#      On_Base_Plus_Slugging_Percentage  On_Base_Plus_Slugging_Percentage_Plus  \
# 110                             0.632                                     71
# 212                             0.642                                     68
#
#      Total_Bases  Double_Plays_Grounded_Into  Times_Hit_By_Pitch  \
# 110          110                         7.0                   1
# 212           44                         2.0                   3
#
#      Sacrifice_Hits  Sacrifice_Flies  Intentional_Bases_on_Balls  \
# 110               5                1                           2
# 212               3                0                           2
#
#     Dominant_Hand Switch_Hitter
# 110         Right            No
# 212         Right           Yes

# %%
phillies_data = phillies_data.dropna(subset = ['Strikeouts'])
phillies_data['Strikeouts'].isnull().sum()
# Out:
# np.int64(0)

# %% [raw]
# NAs are removed for Strikeouts because we have no way of filling the data because taking the mean or another summary statistic wouldnt mean anything.

# %%
missing = phillies_data[phillies_data['Slugging_Percentage'].isnull()]
missing
# Out:
#      Rank  Year Position            Name  Age  Games  Plate_Appearances  \
# 17     18  2023       CI      Drew Ellis   27     12                 29
# 159     4  2020       SS  Didi Gregorius   30     60                237
# 268    10  2018        C    Andrew Knapp   26     84                215
# 366     7  2016       CF  Odúbel Herrera   24    159                656
# 397    37  2016        P   Colton Murray   26     22                  1
#
#      At_Bats  Runs  Hits  Doubles  Triples  Home_Runs  Runs_Batted_In  \
# 17        23     4     5      0.0        0          2               4
# 159      215    34    61     10.0        2         10              40
# 268      187    19    37      6.0        2          4              15
# 366      583    87   167     21.0        6         15              49
# 397        1     0     0      0.0        0          0               0
#
#      Stolen_Bases  Caught_Stealing  Base_On_Balls  Strikeouts  \
# 17            0.0                1              6         7.0
# 159           3.0                2             15        28.0
# 268           1.0                0             24        75.0
# 366          25.0                7             63       134.0
# 397           0.0                0              0         1.0
#
#      Batting_Average  On_Base_Percentage  Slugging_Percentage  \
# 17             0.217               0.379                  NaN
# 159            0.284               0.339                  NaN
# 268            0.198               0.294                  NaN
# 366            0.286               0.361                  NaN
# 397            0.000               0.000                  NaN
#
#      On_Base_Plus_Slugging_Percentage  On_Base_Plus_Slugging_Percentage_Plus  \
# 17                              0.858                                    134
# 159                             0.827                                    120
# 268                             0.610                                     64
# 366                             0.781                                    109
# 397                             0.000                                   -100
#
#      Total_Bases  Double_Plays_Grounded_Into  Times_Hit_By_Pitch  \
# 17            11                         0.0                   0
# 159          105                         4.0                   4
# 268           59                         2.0                   2
# 366          245                         6.0                   6
# 397            0                         0.0                   0
#
#      Sacrifice_Hits  Sacrifice_Flies  Intentional_Bases_on_Balls  \
# 17                0                0                           0
# 159               1                2                           3
# 268               1                1                           1
# 366               2                2                           7
# 397               0                0                           0
#
#     Dominant_Hand Switch_Hitter
# 17          Right            No
# 159          Left            No
# 268         Right           Yes
# 366          Left            No
# 397         Right            No

# %%
calc_slug_per = missing['Slugging_Percentage'] = (missing['Total_Bases'] / missing['At_Bats'])
calc_slug_per
# Out:
# C:\Users\curna\AppData\Local\Temp\ipykernel_13596\2189962476.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   calc_slug_per = missing['Slugging_Percentage'] = (missing['Total_Bases'] / missing['At_Bats'])
# 17     0.478261
# 159    0.488372
# 268    0.315508
# 366    0.420240
# 397    0.000000
# dtype: float64

# %%
phillies_data.iloc[16, 20] = 0.478

# %%
phillies_data.iloc[154, 20] = 0.488

# %%
phillies_data.iloc[257, 20] = 0.316

# %%
phillies_data.iloc[354, 20] = 0.420

# %%
phillies_data.iloc[384, 20] = 0.0

# %%
phillies_data['Slugging_Percentage'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Missing Slugging Percentages can be calculated by filtering the rows with missing data and taking each players total bases and at bats to find the slugging percentage. After that I used the .iloc method to index the player and slugging percentage column to input the slugging percentages.

# %%
phillies_data[phillies_data['Double_Plays_Grounded_Into'].isnull()]
# Out:
#      Rank  Year Position                  Name  Age  Games  Plate_Appearances  \
# 154    54  2021        P  Seranthony Domínguez   26      1                  0
# 205     4  2019       SS           Jean Segura   29    144                618
# 320    12  2017        C          Andrew Knapp   25     56                204
# 420    11  2015       UT             Darin Ruf   28    106                297
#
#      At_Bats  Runs  Hits  Doubles  Triples  Home_Runs  Runs_Batted_In  \
# 154        0     0     0      0.0        0          0               0
# 205      576    79   161     37.0        4         12              60
# 320      171    26    44      8.0        1          3              13
# 420      268    30    63     12.0        0         12              39
#
#      Stolen_Bases  Caught_Stealing  Base_On_Balls  Strikeouts  \
# 154           0.0                0              0         0.0
# 205          10.0                2             30        73.0
# 320           1.0                0             31        56.0
# 420           1.0                0             21        69.0
#
#      Batting_Average  On_Base_Percentage  Slugging_Percentage  \
# 154            0.000               0.000                0.000
# 205            0.280               0.323                0.420
# 320            0.257               0.368                0.368
# 420            0.235               0.300                0.414
#
#      On_Base_Plus_Slugging_Percentage  On_Base_Plus_Slugging_Percentage_Plus  \
# 154                             0.000                                      0
# 205                             0.743                                     91
# 320                             0.736                                     96
# 420                             0.714                                     96
#
#      Total_Bases  Double_Plays_Grounded_Into  Times_Hit_By_Pitch  \
# 154            0                         NaN                   0
# 205          242                         NaN                   8
# 320           63                         NaN                   0
# 420          111                         NaN                   5
#
#      Sacrifice_Hits  Sacrifice_Flies  Intentional_Bases_on_Balls  \
# 154               0                0                           0
# 205               1                3                           1
# 320               0                2                           4
# 420               0                3                           0
#
#     Dominant_Hand Switch_Hitter
# 154         Right            No
# 205         Right            No
# 320         Right           Yes
# 420         Right            No

# %%
phillies_data = phillies_data.dropna(subset = ['Double_Plays_Grounded_Into'])
phillies_data['Double_Plays_Grounded_Into'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# NAs are removed for Double Plays Grounded Into beacuse we have no way of filling or knowing how many double plays they grounded out in.

# %%
phillies_data[phillies_data['Dominant_Hand'].isnull()]
# Out:
#      Rank  Year Position            Name  Age  Games  Plate_Appearances  \
# 5       6  2023       LF  Kyle Schwarber   30    160                720
# 343    35  2017        P  Jesen Therrien   24     14                  2
#
#      At_Bats  Runs  Hits  Doubles  Triples  Home_Runs  Runs_Batted_In  \
# 5        585   108   115     19.0        1         47             104
# 343        2     0     0      0.0        0          0               0
#
#      Stolen_Bases  Caught_Stealing  Base_On_Balls  Strikeouts  \
# 5             0.0                2            126       215.0
# 343           0.0                0              0         2.0
#
#      Batting_Average  On_Base_Percentage  Slugging_Percentage  \
# 5              0.197               0.343                0.474
# 343            0.000               0.000                0.000
#
#      On_Base_Plus_Slugging_Percentage  On_Base_Plus_Slugging_Percentage_Plus  \
# 5                               0.817                                    122
# 343                             0.000                                   -100
#
#      Total_Bases  Double_Plays_Grounded_Into  Times_Hit_By_Pitch  \
# 5            277                         4.0                   6
# 343            0                         0.0                   0
#
#      Sacrifice_Hits  Sacrifice_Flies  Intentional_Bases_on_Balls  \
# 5                 0                3                           5
# 343               0                0                           0
#
#     Dominant_Hand Switch_Hitter
# 5             NaN            No
# 343           NaN            No

# %%
phillies_data[phillies_data['Name'] == 'Kyle Schwarber']
# Out:
#     Rank  Year Position            Name  Age  Games  Plate_Appearances  \
# 5      6  2023       LF  Kyle Schwarber   30    160                720
# 49     6  2022       LF  Kyle Schwarber   29    155                669
#
#     At_Bats  Runs  Hits  Doubles  Triples  Home_Runs  Runs_Batted_In  \
# 5       585   108   115     19.0        1         47             104
# 49      577   100   126     21.0        3         46              94
#
#     Stolen_Bases  Caught_Stealing  Base_On_Balls  Strikeouts  Batting_Average  \
# 5            0.0                2            126       215.0            0.197
# 49          10.0                1             86       200.0            0.218
#
#     On_Base_Percentage  Slugging_Percentage  On_Base_Plus_Slugging_Percentage  \
# 5                0.343                0.474                             0.817
# 49               0.323                0.504                             0.827
#
#     On_Base_Plus_Slugging_Percentage_Plus  Total_Bases  \
# 5                                     122          277
# 49                                    131          291
#
#     Double_Plays_Grounded_Into  Times_Hit_By_Pitch  Sacrifice_Hits  \
# 5                          4.0                   6               0
# 49                        10.0                   4               0
#
#     Sacrifice_Flies  Intentional_Bases_on_Balls Dominant_Hand Switch_Hitter
# 5                 3                           5           NaN            No
# 49                2                           3          Left            No

# %%
phillies_data[phillies_data['Name'] == 'Jesen Therrien']
# Out:
#      Rank  Year Position            Name  Age  Games  Plate_Appearances  \
# 343    35  2017        P  Jesen Therrien   24     14                  2
#
#      At_Bats  Runs  Hits  Doubles  Triples  Home_Runs  Runs_Batted_In  \
# 343        2     0     0      0.0        0          0               0
#
#      Stolen_Bases  Caught_Stealing  Base_On_Balls  Strikeouts  \
# 343           0.0                0              0         2.0
#
#      Batting_Average  On_Base_Percentage  Slugging_Percentage  \
# 343              0.0                 0.0                  0.0
#
#      On_Base_Plus_Slugging_Percentage  On_Base_Plus_Slugging_Percentage_Plus  \
# 343                               0.0                                   -100
#
#      Total_Bases  Double_Plays_Grounded_Into  Times_Hit_By_Pitch  \
# 343            0                         0.0                   0
#
#      Sacrifice_Hits  Sacrifice_Flies  Intentional_Bases_on_Balls  \
# 343               0                0                           0
#
#     Dominant_Hand Switch_Hitter
# 343           NaN            No

# %%
phillies_data.iloc[5, 29] = 'Left'

# %%
phillies_data = phillies_data.dropna(subset = ['Dominant_Hand'])
phillies_data['Dominant_Hand'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# since kyle schwarber has another row of data from another year we can see what his dominant hand is and input it in for the other row. Jesen Therrien only has one season with the philles so there is no way to find his dominant hand so we drop the row.

# %%
phillies_data.shape
# Out:
# (442, 31)

# %% [markdown]
# After removing or filling the NAs we have gotten ride of 18 rows of data.

# %%
phillies_data.isnull().sum()
# Out:
# Rank                                     0
# Year                                     0
# Position                                 0
# Name                                     0
# Age                                      0
# Games                                    0
# Plate_Appearances                        0
# At_Bats                                  0
# Runs                                     0
# Hits                                     0
# Doubles                                  0
# Triples                                  0
# Home_Runs                                0
# Runs_Batted_In                           0
# Stolen_Bases                             0
# Caught_Stealing                          0
# Base_On_Balls                            0
# Strikeouts                               0
# Batting_Average                          0
# On_Base_Percentage                       0
# Slugging_Percentage                      0
# On_Base_Plus_Slugging_Percentage         0
# On_Base_Plus_Slugging_Percentage_Plus    0
# Total_Bases                              0
# Double_Plays_Grounded_Into               0
# Times_Hit_By_Pitch                       0
# Sacrifice_Hits                           0
# Sacrifice_Flies                          0
# Intentional_Bases_on_Balls               0
# Dominant_Hand                            0
# Switch_Hitter                            0
# dtype: int64

# %%
phillies_duplicated_rows = phillies_data[phillies_data.duplicated()]
phillies_duplicated_rows
# Out:
#      Rank  Year Position              Name  Age  Games  Plate_Appearances  \
# 53      9  2022       DH      Bryce Harper   29     99                426
# 207     5  2019       3B     Maikel Franco   26    123                428
# 282    23  2018        P      Jake Arrieta   32     28                 50
# 319    11  2017       UT      Rhys Hoskins   24     50                212
# 378    18  2016       UT  Emmanuel Burriss   31     39                 50
#
#      At_Bats  Runs  Hits  Doubles  Triples  Home_Runs  Runs_Batted_In  \
# 53       370    63   106     28.0        1         18              65
# 207      389    48    91     17.0        0         17              56
# 282       45     3     6      0.0        0          1               3
# 319      170    37    44      7.0        0         18              48
# 378       45     3     5      1.0        1          0               0
#
#      Stolen_Bases  Caught_Stealing  Base_On_Balls  Strikeouts  \
# 53           11.0                4             46        87.0
# 207           0.0                0             36        61.0
# 282           0.0                0              3        27.0
# 319           2.0                0             37        46.0
# 378           1.0                0              2        10.0
#
#      Batting_Average  On_Base_Percentage  Slugging_Percentage  \
# 53             0.286               0.364                0.514
# 207            0.234               0.297                0.409
# 282            0.133               0.188                0.200
# 319            0.259               0.396                0.618
# 378            0.111               0.184                0.178
#
#      On_Base_Plus_Slugging_Percentage  On_Base_Plus_Slugging_Percentage_Plus  \
# 53                              0.877                                    146
# 207                             0.705                                     81
# 282                             0.388                                      4
# 319                             1.014                                    162
# 378                             0.361                                     -2
#
#      Total_Bases  Double_Plays_Grounded_Into  Times_Hit_By_Pitch  \
# 53           190                        13.0                   3
# 207          159                        14.0                   0
# 282            9                         1.0                   0
# 319          105                         2.0                   3
# 378            8                         1.0                   2
#
#      Sacrifice_Hits  Sacrifice_Flies  Intentional_Bases_on_Balls  \
# 53                0                7                           9
# 207               0                3                          19
# 282               2                0                           0
# 319               0                2                           1
# 378               1                0                           0
#
#     Dominant_Hand Switch_Hitter
# 53           Left            No
# 207         Right            No
# 282         Right            No
# 319         Right            No
# 378         Right           Yes

# %%
phillies_data = phillies_data.drop_duplicates()
phillies_data.shape
# Out:
# (437, 31)

# %% [markdown]
# There were 5 rows of duplicate data and after dropping the duplicates we have finished cleaning the dataset and have removed 23 rows of data.

# %% [markdown]
# ## Principles of DM

# %% [markdown]
# The 2 principles of data management I want to discuss are Data Accessibility and Data Lifecycle Management.
#
# Data Accessibilty is important in my opinion because having access to data that you need at a certain moment can be the crucial for decision-making that is accurate and efficient. Being able to have data/information when needed will save time and allow you to be more efficient. One important process with data accessibility is making sure that the data that is being shared is with only the people that should have it. Making sure the data is protected and secure so no-one who shouldnt have it, wont have access to it. Lastly, making sure the data is in a well and usable format for the intended people who need access to it is crucial.
#
# Data Lifecycle Management is something I never really thought of as being this important til I learned about it. Data Lifecycle Management is handling data from its creation to deletion. I've always thought that when data is collected, it just stays stored somewhere and eventually forgot about, as it becomes less important. Learning about this principle it has a lot more to it and is much more important than I previously thought. The data is first created, then it is stored somewhere, where it is secure and protected and only authorized to people that need it. After it is used, it gets stored away in a secure manner, that allows it to be used, if needed in the future. Finally, if it is no longer needed or stroage needs to be freed up, then it is deleted. Manageing this whole process takes a lot of energy and ensures that the data is used for what it needs, it doesnt get leaked or used by unauthorized users, all the way until it is deleted.

# %% [markdown]
# ## Principles of FM

# %% [markdown]
# The 2 principles of file management I want to discuss are Keeping original version of program and data files, and Placing comments and notes in the data files.
#
# Keeping original files and programs are very important in my opinion. Especially with data, it is so easy to lose or delete something by accident. I also feel like there is not much forgiveness when you delete or lose something, as it is almost always impoosible to recover something you delete. Making sure you make copies or backups of data or files you are working with because it is so easy to permanently change something that you didnt want to or delete something that you can not get back. Having backups makes it so that lost data can be recovered.
#
# Placing comments and notes in files is important because it allows all the code to be readable and understood. If you have a file of a bunch of code, it would probably take someone very long to understand it all, which they most likely would forget if they had to go back to it another day. Making sure your code or data is has comments throught the file, makes it so anyone could understand what your code is doing and what it all means.

# %% [markdown]
# ## Discussion of LLM Usage

# %% [markdown]
# LLM most definetly has its benefits as it can be used as a tool to help with errors or mistakes you are stuck on, used to help describe things you are working on, and help with any question you have or to find topics or things to work on. On the other hand, it has its cons. People can tend to abuse the usage of LLM, as it can be used to load data, and almost answer and do any problem you need. People can tend to lean on it too much and not retain or know anything about what they are doing. LLM usage has definetly increased productivity, but its the problem of if it is actually being used to help, or is it being used to do all the work. I think LLM is a great thing, but it can be abused and lead to problems down the road.
